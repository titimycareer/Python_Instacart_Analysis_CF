# %% [markdown]
# # 01. Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Import Data

# %%
df = pd.read_csv(r'C:\Users\tee3a\3D Objects\12-2022 Instacart Basket Analysis\02 Data\Original Data for raw data sets\orders.csv', index_col = False)

# %%
path = r'C:\Users\tee3a\3D Objects\12-2022 Instacart Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\tee3a\\3D Objects\\12-2022 Instacart Basket Analysis'

# %% [markdown]
# # 03 Import order.csv using os libraries

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data for raw data sets', 'orders.csv'), index_col = False)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df.shape
# Out:
# (3421083, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
df.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
df.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data for raw data sets', 'orders.csv'), nrows=1000)

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data for raw data sets', 'orders.csv'), usecols = vars_list)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df.head(100)
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# ..       ...      ...           ...        ...                ...
# 95   1468214       11             7          5                  9
# 96   1376945       11             8          6                 11
# 97   1483446       12             1          1                 12
# 98   1247527       12             2          5                  9
# 99   1916106       12             3          5                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# ...

# %% [markdown]
# # 04 Orders data dictionary

# %%
data_dict_ords = df.to_dict('index')

# %%
data_dict_ords
# Out:
# {0: {'order_id': 2539329,
#   'user_id': 1,
#   'order_number': 1,
#   'order_dow': 2,
#   'order_hour_of_day': 8,
#   'days_since_prior_order': nan},
#  1: {'order_id': 2398795,
#   'user_id': 1,
#   'order_number': 2,
#   'order_dow': 3,
#   'order_hour_of_day': 7,
#   'days_since_prior_order': 15.0},
#  2: {'order_id': 473747,
#   'user_id': 1,
#   'order_number': 3,
#   'order_dow': 3,
#   'order_hour_of_day': 12,
#   'days_since_prior_order': 21.0},
#  3: {'order_id': 2254736,
#   'user_id': 1,
#   'order_number': 4,
#   'order_dow': 4,
#   'order_hour_of_day': 7,
#   'days_since_prior_order': 29.0},
#  4: {'order_id': 431534,
#   'user_id': 1,
#   'order_number': 5,
#   'order_dow': 4,
#   'order_hour_of_day': 15,
#   'days_since_prior_order': 28.0},
#  5: {'order_id': 3367565,
#   'user_id': 1,
#   'order_number': 6,
#   'order_dow': 2,
#   'order_hour_of_day': 7,
#   'days_since_prior_order': 19.0},
#  6: {'order_id': 550135,
#   'user_id': 1,
#   'order_number': 7,
# ...

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
print(data_dict_ords.get('2.3'))
# Out:
# None

# %%
df['order_hour_of_day'].describe()
# Out:
# count    3.421083e+06
# mean     1.345202e+01
# std      4.226088e+00
# min      0.000000e+00
# 25%      1.000000e+01
# 50%      1.300000e+01
# 75%      1.600000e+01
# max      2.300000e+01
# Name: order_hour_of_day, dtype: float64

# %%
df['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
df.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %% [markdown]
# # 05 Import product.csv using os libraries

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data for raw data sets', 'products.csv'), index_col = False)

# %%
data_dict_prods = df_prods.to_dict('index')

# %% [markdown]
# # 04 Products data dictionary

# %%
data_dict_prods
# Out:
# {0: {'product_id': 1,
#   'product_name': 'Chocolate Sandwich Cookies',
#   'aisle_id': 61,
#   'department_id': 19,
#   'prices': 5.8},
#  1: {'product_id': 2,
#   'product_name': 'All-Seasons Salt',
#   'aisle_id': 104,
#   'department_id': 13,
#   'prices': 9.3},
#  2: {'product_id': 3,
#   'product_name': 'Robust Golden Unsweetened Oolong Tea',
#   'aisle_id': 94,
#   'department_id': 7,
#   'prices': 4.5},
#  3: {'product_id': 4,
#   'product_name': 'Smart Ones Classic Favorites Mini Rigatoni With Vodka Cream Sauce',
#   'aisle_id': 38,
#   'department_id': 1,
#   'prices': 10.5},
#  4: {'product_id': 5,
#   'product_name': 'Green Chile Anytime Sauce',
#   'aisle_id': 5,
#   'department_id': 13,
#   'prices': 4.3},
#  5: {'product_id': 6,
#   'product_name': 'Dry Nose Oil',
#   'aisle_id': 11,
#   'department_id': 11,
#   'prices': 2.6},
#  6: {'product_id': 7,
#   'product_name': 'Pure Coconut Water With Orange',
#   'aisle_id': 98,
#   'department_id': 7,
#   'prices': 4.4},
# ...

# %%
df_prods['department_id'].value_counts(dropna = False)
# Out:
# 11    6565
# 19    6264
# 13    5371
# 7     4365
# 1     4007
# 16    3449
# 17    3085
# 15    2092
# 9     1858
# 4     1684
# 3     1516
# 20    1322
# 21    1258
# 6     1139
# 14    1116
# 18    1081
# 5     1056
# 8      972
# 12     907
# 2      548
# 10      38
# Name: department_id, dtype: int64

# %%
df_breakfast = df_prods.loc[df_prods['department_id'] == 14]

# %%
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
df_alcohol =  df_prods[df_prods['department_id']==5]

# %%
 df_alcohol
# Out:
#        product_id                               product_name  aisle_id  \
# 51             52                        Mirabelle Brut Rose       134
# 118           119                     Chardonnay Paso Robles        62
# 149           150                                  Brut Rosé       134
# 233           234                          Tennessee Whiskey       124
# 248           249             Pinot Grigio, California, 2010        62
# ...           ...                                        ...       ...
# 49548       49544                    Cabernet Sauvignon Wine        28
# 49566       49562              Blanc De Noirs Sparkling Wine       134
# 49610       49606                        Organic Natural Red        28
# 49665       49661                                      Porto       134
# 49688       49684  Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# 51                 5    14.4
# 118                5     5.5
# ...

# %%
df_deli =  df_prods[df_prods['department_id']==20]

# %%
df_beverages =  df_prods[df_prods['department_id']==7]

# %%
df_meatseafood =  df_prods[df_prods['department_id']==12]

# %%
df_inquiries = df_alcohol + df_deli + df_beverages + df_meatseafood

# %%
df_inquiries
# Out:
#        product_id product_name  aisle_id  department_id  prices
# 2             NaN          NaN       NaN            NaN     NaN
# 6             NaN          NaN       NaN            NaN     NaN
# 9             NaN          NaN       NaN            NaN     NaN
# 10            NaN          NaN       NaN            NaN     NaN
# 16            NaN          NaN       NaN            NaN     NaN
# ...           ...          ...       ...            ...     ...
# 49676         NaN          NaN       NaN            NaN     NaN
# 49679         NaN          NaN       NaN            NaN     NaN
# 49680         NaN          NaN       NaN            NaN     NaN
# 49686         NaN          NaN       NaN            NaN     NaN
# 49688         NaN          NaN       NaN            NaN     NaN
#
# [7650 rows x 5 columns]

# %%
df['user_id'].value_counts(dropna = False)
# Out:
# 152340    100
# 185641    100
# 185524    100
# 81678     100
# 70922     100
#          ...
# 13046       4
# 70208       4
# 111440      4
# 31762       4
# 47980       4
# Name: user_id, Length: 206209, dtype: int64

# %%
df_user_id_1_information = df.loc[df['user_id'] == 1]

# %%
df_user_id_1_information
# Out:
#     order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1             1          2                  8
# 1    2398795        1             2          3                  7
# 2     473747        1             3          3                 12
# 3    2254736        1             4          4                  7
# 4     431534        1             5          4                 15
# 5    3367565        1             6          2                  7
# 6     550135        1             7          1                  9
# 7    3108588        1             8          1                 14
# 8    2295261        1             9          1                 16
# 9    2550362        1            10          4                  8
# 10   1187899        1            11          4                  8
#
#     days_since_prior_order
# 0                      NaN
# 1                     15.0
# 2                     21.0
# 3                     29.0
# 4                     28.0
# ...
